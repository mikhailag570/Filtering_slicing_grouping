# %%
import pandas as pd
dataset = pd.read_csv('movies_clean.csv')
dataset.head()
# Out:
#    Unnamed: 0                                             poster  \
# 0           0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1           1  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2           2  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3           3  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4           4  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime                      genre  \
# 0  The Shawshank Redemption          15  142 min                      Drama
# 1            Hababam Sinifi         12A   87 min              Comedy, Drama
# 2             The Godfather           X  175 min               Crime, Drama
# 3    The Godfather: Part II           X  202 min               Crime, Drama
# 4          Schindler's List          15  195 min  Biography, Drama, History
#
#    rating                                              about  \
# ...

# %%
'''
Удаляем столбец Unnamed
'''

# %%
dataset.drop(columns='Unnamed: 0', inplace=True)

# %%
dataset.shape
# Out:
# (4970, 13)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4970 entries, 0 to 4969
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   poster            4970 non-null   object
#  1   title             4970 non-null   object
#  2   certificate       4970 non-null   object
#  3   runtime           4970 non-null   object
#  4   genre             4970 non-null   object
#  5   rating            4970 non-null   float64
#  6   about             4956 non-null   object
#  7   director          4970 non-null   object
#  8   stars             4970 non-null   object
#  9   votes             4970 non-null   object
#  10  gross_earn        4574 non-null   float64
#  11  runtime_clear     4970 non-null   int64
#  12  gross_earn_clear  4574 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 504.9+ KB

# %%
'''
Выбираем фильм, по образцу "Jurassic Park".
Режиссер фильма "Jurassic Park" - Steven Spielberg.
'''

# %%
filter = dataset['director'] == 'Steven Spielberg'
filtered_dataset = dataset[filter]

filtered_dataset.head()
# Out:
#                                                 poster  \
# 4    https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 75   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 160  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 168  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                   title certificate  runtime  \
# 4                      Schindler's List          15  195 min
# 24                  Saving Private Ryan          15  169 min
# 75              Raiders of the Lost Ark           A  115 min
# 160                       Jurassic Park          PG  127 min
# 168  Indiana Jones and the Last Crusade          PG  127 min
#
#                          genre  rating  \
# 4    Biography, Drama, History     9.0
# 24                  Drama, War     8.6
# 75           Action, Adventure     8.4
# 160  Action, Adventure, Sci-Fi     8.2
# 168          Action, Adventure     8.2
#
# ...

# %%
filtered_dataset.shape
# Out:
# (27, 13)

# %%
'''
Отфильтруем датасет, оставив фильмы с рейтингом выше 7.0 баллов, и сохраним результаты в переменную filtered_dataset_2
'''

# %%
filter_2 = filtered_dataset['rating'] > 7.0
filtered_dataset_2 = filtered_dataset[filter_2]

filtered_dataset_2.head()
# Out:
#                                                 poster  \
# 4    https://m.media-amazon.com/images/S/sash/4Fyxw...
# 24   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 75   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 160  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 168  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                   title certificate  runtime  \
# 4                      Schindler's List          15  195 min
# 24                  Saving Private Ryan          15  169 min
# 75              Raiders of the Lost Ark           A  115 min
# 160                       Jurassic Park          PG  127 min
# 168  Indiana Jones and the Last Crusade          PG  127 min
#
#                          genre  rating  \
# 4    Biography, Drama, History     9.0
# 24                  Drama, War     8.6
# 75           Action, Adventure     8.4
# 160  Action, Adventure, Sci-Fi     8.2
# 168          Action, Adventure     8.2
#
# ...

# %%
filtered_dataset_2.shape
# Out:
# (21, 13)

# %%
filtered_dataset_2['certificate'].unique()
# Out:
# array(['15', 'A', 'PG', '12A', 'U', '12'], dtype=object)

# %%
'''
Из данных классов нам подходят:

A (с детского возраста под присмотром родителей по старой классификации)
PG (с детского возраста под присмотром родителей)
U (для людей всех возрастов)
UA (для людей всех возрастов, под присмотром родителей по старой классификации)
'''

# %%
certificate = ['A', 'PG', 'U', 'UA']

filter_3 = filtered_dataset_2['certificate'].isin(certificate)

filtered_dataset_3 = filtered_dataset_2[filter_3]

filtered_dataset_3.head(21)
# Out:
#                                                  poster  \
# 75    https://m.media-amazon.com/images/S/sash/4Fyxw...
# 160   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 168   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 253   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 477   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 676   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 830   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1324  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                                   title certificate  runtime  \
# 75                              Raiders of the Lost Ark           A  115 min
# 160                                       Jurassic Park          PG  127 min
# 168                  Indiana Jones and the Last Crusade          PG  127 min
# 253                                                Jaws           A  124 min
# ...

# %%
filtered_dataset_3.shape
# Out:
# (8, 13)

# %%
'''
Исключим фильмы, которые уже пересмотрели:

Jurassic Park
Indiana Jones and the Last Crusade
Jaws
И выберем самый короткий фильм из оставшихся.
'''

# %%
stop_films = ['Jurassic Park', 'Indiana Jones and the Last Crusade', 'Jaws']

filter_4 = (~(filtered_dataset_3['title'].isin(stop_films))&(filtered_dataset_3['runtime_clear']==filtered_dataset_3['runtime_clear'].min()))

filtered_dataset_4 = filtered_dataset_3[filter_4]

filtered_dataset_4
# Out:
#                                                  poster  \
# 1324  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                                   title certificate  runtime  \
# 1324  The Adventures of Tintin: The Secret of the Un...          PG  107 min
#
#                              genre  rating  \
# 1324  Animation, Action, Adventure     7.3
#
#                                                   about          director  \
# 1324  Intrepid reporter Tintin and Captain Haddock s...  Steven Spielberg
#
#                                                   stars     votes  gross_earn  \
# 1324  ('Jamie Bell',), ('Andy Serkis',), ('Daniel Cr...  2,30,302      7759.0
#
#       runtime_clear  gross_earn_clear
# 1324            107            7759.0

# %%
filtered_dataset_4['title'][1324]
# Out:
# 'The Adventures of Tintin: The Secret of the Unicorn'

# %%
'''
По аналогии отфильтруем датасет таким образом, чтобы выбрать фильм на вечер для себя
'''

# %%
dataset['director'].value_counts()[:5]
# Out:
# Woody Allen         38
# Clint Eastwood      27
# Steven Spielberg    27
# Alfred Hitchcock    24
# Ridley Scott        21
# Name: director, dtype: int64

# %%
filter = dataset['director'] == 'Alfred Hitchcock'
filtered_dataset = dataset[filter]
filtered_dataset.head()
# Out:
#                                                 poster               title  \
# 33   https://m.media-amazon.com/images/S/sash/4Fyxw...              Psycho
# 36   https://m.media-amazon.com/images/S/sash/4Fyxw...         Rear Window
# 96   https://m.media-amazon.com/images/S/sash/4Fyxw...             Vertigo
# 107  https://m.media-amazon.com/images/S/sash/4Fyxw...  North by Northwest
# 166  https://m.media-amazon.com/images/S/sash/4Fyxw...   Dial M for Murder
#
#     certificate  runtime                       genre  rating  \
# 33           15  109 min   Horror, Mystery, Thriller     8.5
# 36            A  112 min           Mystery, Thriller     8.5
# 96            A  128 min  Mystery, Romance, Thriller     8.3
# 107           A  136 min  Action, Adventure, Mystery     8.3
# 166          PG  105 min             Crime, Thriller     8.2
#
#                                                  about          director  \
# ...

# %%
filtered_dataset.shape
# Out:
# (24, 13)

# %%
'''
Выбор по рейтингу более чем 8 и максимальной продолжительности
'''

# %%
filter_2 = ((filtered_dataset['rating']>8.0)&(filtered_dataset['runtime_clear']==filtered_dataset['runtime_clear'].max()))
filtered_dataset_2 = filtered_dataset[filter_2]

filtered_dataset_2.head()
# Out:
#                                                 poster               title  \
# 107  https://m.media-amazon.com/images/S/sash/4Fyxw...  North by Northwest
#
#     certificate  runtime                       genre  rating  \
# 107           A  136 min  Action, Adventure, Mystery     8.3
#
#                                                  about          director  \
# 107  A New York City advertising executive goes on ...  Alfred Hitchcock
#
#                                                  stars     votes  gross_earn  \
# 107  ('Cary Grant',), ('Eva Marie Saint',), ('James...  3,24,896      1328.0
#
#      runtime_clear  gross_earn_clear
# 107            136            1328.0

# %%
filtered_dataset_2['title'][107]
# Out:
# 'North by Northwest'

# %%
'''
Выбираем еще 2 детских фильма, близких по рейтингу к выбранному/
'''

# %%
dataset.loc[1324]
# Out:
# poster              https://m.media-amazon.com/images/S/sash/4Fyxw...
# title               The Adventures of Tintin: The Secret of the Un...
# certificate                                                        PG
# runtime                                                       107 min
# genre                                    Animation, Action, Adventure
# rating                                                            7.3
# about               Intrepid reporter Tintin and Captain Haddock s...
# director                                             Steven Spielberg
# stars               ('Jamie Bell',), ('Andy Serkis',), ('Daniel Cr...
# votes                                                        2,30,302
# gross_earn                                                     7759.0
# runtime_clear                                                     107
# gross_earn_clear                                               7759.0
# Name: 1324, dtype: object

# %%
dataset.loc[1324]['about']
# Out:
# "Intrepid reporter Tintin and Captain Haddock set off on a treasure hunt for a sunken ship commanded by Haddock's ancestor."

# %%
'''
Сократим диапазон поиска, выбрав срез фильмов от 1320 строки до 1330 строки
'''

# %%
dataset.loc[1320:1330]
# Out:
#                                                  poster  \
# 1320  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1321  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1322  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1323  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1324  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1325  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1326  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1327  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1328  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1329  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1330  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                                   title certificate  runtime  \
# 1320                      Star Trek IV: The Voyage Home          PG  119 min
# 1321                       Murder on the Orient Express           A  128 min
# ...

# %%
'''
Из полученных в результате среза фильмов подходят только фильмы жанра Animation. Это фильмы с индексами 1323 и 1328.
'''

# %%
index_list = [1323, 1324, 1328]
dataset.loc[index_list]
# Out:
#                                                  poster  \
# 1323  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1324  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1328  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                                   title certificate  runtime  \
# 1323                                         Cinderella           U   74 min
# 1324  The Adventures of Tintin: The Secret of the Un...          PG  107 min
# 1328                                    Despicable Me 2           U   98 min
#
#                              genre  rating  \
# 1323    Animation, Family, Fantasy     7.3
# 1324  Animation, Action, Adventure     7.3
# 1328  Animation, Adventure, Comedy     7.3
#
#                                                   about          director  \
# 1323  When Cinderella's cruel stepmother prevents he...    Clyde Geronimi
# 1324  Intrepid reporter Tintin and Captain Haddock s...  Steven Spielberg
# ...

# %%
'''
в переменной filtered_dataset ранее был сохранен датасет с фильмами кинорежиссера Steven Spielberg. 
Выберем различные показатели описательной статистики.
'''

# %%
described_data = filtered_dataset.describe()
described_data
# Out:
#           rating  gross_earn  runtime_clear  gross_earn_clear
# count  24.000000     15.0000      24.000000           15.0000
# mean    7.675000   1128.0000     109.666667         1128.0000
# std     0.491006   1010.1461      14.208591         1010.1461
# min     6.600000      1.0000      80.000000            1.0000
# 25%     7.400000    575.0000     100.500000          575.0000
# 50%     7.600000    875.0000     108.500000          875.0000
# 75%     7.950000   1200.0000     119.250000         1200.0000
# max     8.500000   3676.0000     136.000000         3676.0000

# %%
described_data.loc['min']
# Out:
# rating               6.6
# gross_earn           1.0
# runtime_clear       80.0
# gross_earn_clear     1.0
# Name: min, dtype: float64

# %%
'''
Выведите срез строк от 50% процентиля до максимального значения
'''

# %%
described_data.loc['50%':'max']
# Out:
#      rating  gross_earn  runtime_clear  gross_earn_clear
# 50%    7.60       875.0         108.50             875.0
# 75%    7.95      1200.0         119.25            1200.0
# max    8.50      3676.0         136.00            3676.0

# %%
'''
Выведем срез от минимального (min) до максимального (max) значения
'''

# %%
described_data.iloc[3:8]
# Out:
#      rating  gross_earn  runtime_clear  gross_earn_clear
# min    6.60         1.0          80.00               1.0
# 25%    7.40       575.0         100.50             575.0
# 50%    7.60       875.0         108.50             875.0
# 75%    7.95      1200.0         119.25            1200.0
# max    8.50      3676.0         136.00            3676.0

# %%
'''
Выбираем еще пять фильмов, близких к предыдущему.
Методом проб и ошибок, здесь результат.
'''

# %%
dataset.loc[1345:1420]
# Out:
#                                                  poster  \
# 1345  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1346  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1347  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1348  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1349  https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...                                                 ...
# 1416  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1417  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1418  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1419  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1420  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                        title certificate  runtime  \
# 1345   Shaun the Sheep Movie           U   85 min
# 1346            Men in Black          PG   98 min
# 1347          Eye in the Sky          15  102 min
# 1348    Deconstructing Harry          15   96 min
# ...

# %%
'''
Делалось за несколько подходов.
Дальше результат
'''

# %%
sorted_films = [1345, 1349, 1364, 1389, 1405]
sorted_films_dataset = dataset.loc[sorted_films]
sorted_films_dataset
# Out:
#                                                  poster  \
# 1345  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1349  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1364  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1389  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1405  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime  \
# 1345  Shaun the Sheep Movie           U   85 min
# 1349    Monsters University           U  104 min
# 1364               Hercules           U   93 min
# 1389     The Simpsons Movie          PG   87 min
# 1405       The Last Unicorn           U   92 min
#
#                              genre  rating  \
# 1345  Animation, Adventure, Comedy     7.3
# 1349  Animation, Adventure, Comedy     7.3
# 1364  Animation, Adventure, Comedy     7.3
# 1389  Animation, Adventure, Comedy     7.3
# 1405   Animation, Adventure, Drama     7.3
#
# ...

# %%
filter = dataset['genre'] == 'Animation, Adventure, Comedy'
filtered_dataset_animation = dataset[filter]
filtered_dataset_animation
# Out:
#                                                  poster  \
# 98    https://m.media-amazon.com/images/S/sash/4Fyxw...
# 101   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 109   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 113   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 155   https://m.media-amazon.com/images/S/sash/4Fyxw...
# ...                                                 ...
# 4743  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4829  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4856  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4877  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4879  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                         title certificate  runtime  \
# 98                                         Up           U   96 min
# 101                                 Toy Story          PG   81 min
# 109                               Toy Story 3           U  103 min
# ...

# %%
filter_2 = dataset['rating'] == 7.3
filtered_dataset_animation_2 = filtered_dataset_animation[filter_2]
filtered_dataset_animation_2
# Out:
# C:\Users\Luther\AppData\Local\Temp\ipykernel_23080\3384653197.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_dataset_animation_2 = filtered_dataset_animation[filter_2]
#                                                  poster  \
# 1317  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1328  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1345  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1349  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1364  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1389  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1409  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1424  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1435  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1460  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1505  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime  \
# ...

# %%
'''
Выбираем показатели описательной статистики по фильмам кинорежиссера Woody Allen
'''

# %%
filter = dataset['director'] == 'Woody Allen'
filtered_dataset = dataset[filter]
filtered_dataset.head()
# Out:
#                                                 poster  \
# 329  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 464  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 500  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 636  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 717  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                        title certificate  runtime                   genre  \
# 329               Annie Hall          AA   93 min         Comedy, Romance
# 464   Hannah and Her Sisters          15  107 min           Comedy, Drama
# 500                Manhattan          AA   96 min  Comedy, Drama, Romance
# 636  Crimes and Misdemeanors          15  104 min           Comedy, Drama
# 717           Love and Death           A   85 min             Comedy, War
#
#      rating                                              about     director  \
# 329     8.0  Alvy Singer, a divorced Jewish comedian, refle...  Woody Allen
# ...

# %%
filtered_dataset.shape
# Out:
# (38, 13)

# %%
filtered_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 329 to 3479
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   poster            38 non-null     object
#  1   title             38 non-null     object
#  2   certificate       38 non-null     object
#  3   runtime           38 non-null     object
#  4   genre             38 non-null     object
#  5   rating            38 non-null     float64
#  6   about             38 non-null     object
#  7   director          38 non-null     object
#  8   stars             38 non-null     object
#  9   votes             38 non-null     object
#  10  gross_earn        36 non-null     float64
#  11  runtime_clear     38 non-null     int64
#  12  gross_earn_clear  36 non-null     float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 4.2+ KB

# %%
'''
Отбираем все фильмы жанра Adventure
'''

# %%
def is_genre_correct(genre):
  return 'Adventure' in genre

filter_5 = dataset['genre'].apply(is_genre_correct)
filter_5.tail()
# Out:
# 4965     True
# 4966    False
# 4967    False
# 4968    False
# 4969    False
# Name: genre, dtype: bool

# %%
filtered_dataset_5 = dataset[filter_5]
filtered_dataset_5.head()
# Out:
#                                                poster  \
# 6   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 9   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 11  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 13  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 14  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                                                 title certificate  runtime  \
# 6       The Lord of the Rings: The Return of the King         12A  201 min
# 9   The Lord of the Rings: The Fellowship of the Ring          PG  178 min
# 11              The Lord of the Rings: The Two Towers         12A  179 min
# 13                                          Inception         12A  148 min
# 14                     The Good, the Bad and the Ugly           X  148 min
#
#                         genre  rating  \
# 6    Action, Adventure, Drama     9.0
# 9    Action, Adventure, Drama     8.8
# 11   Action, Adventure, Drama     8.8
# ...

# %%
filtered_dataset_5.shape
# Out:
# (1011, 13)

# %%
'''
Oтфильтруем числовые колонки исходного датасета dataset.
Выведем список признаков с указанием их типов с помощью атрибута dtypes и сохраним результаты в переменную dtypes
'''

# %%
dtypes = dataset.dtypes
dtypes
# Out:
# poster               object
# title                object
# certificate          object
# runtime              object
# genre                object
# rating              float64
# about                object
# director             object
# stars                object
# votes                object
# gross_earn          float64
# runtime_clear         int64
# gross_earn_clear    float64
# dtype: object

# %%
'''
Отфильтруем все числовые колонки и сохраните результаты в переменную num_dtypes.
'''

# %%
num_dtypes = dtypes[dtypes!='object']
num_dtypes
# Out:
# rating              float64
# gross_earn          float64
# runtime_clear         int64
# gross_earn_clear    float64
# dtype: object

# %%
'''
Сохраним в переменную new_columns список наименований колонок.
'''

# %%
new_columns = num_dtypes.index
new_columns
# Out:
# Index(['rating', 'gross_earn', 'runtime_clear', 'gross_earn_clear'], dtype='object')

# %%
'''
Отфильтруем исходный датасет, оставив только числовые колонки
'''

# %%
filtered_dataset_6 = dataset[num_dtypes.index]
filtered_dataset_6.head()
# Out:
#    rating  gross_earn  runtime_clear  gross_earn_clear
# 0     9.3      2834.0            142            2834.0
# 1     9.2         NaN             87               NaN
# 2     9.2     13497.0            175           13497.0
# 3     9.0      5730.0            202            5730.0
# 4     9.0      9690.0            195            9690.0

# %%
'''
Отбираем все фильмы, где снимался Leonardo DiCaprio
'''

# %%
def is_stars_correct(stars):
  return 'Leonardo DiCaprio' in stars

# %%
filter_6 = dataset['stars'].apply(is_stars_correct)

# %%
filtered_dataset_7 = dataset[filter_6]
filtered_dataset_7.head()
# Out:
#                                                 poster  \
# 13   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 52   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 72   https://m.media-amazon.com/images/S/sash/4Fyxw...
# 165  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 167  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                        title certificate  runtime                      genre  \
# 13                 Inception         12A  148 min  Action, Adventure, Sci-Fi
# 52              The Departed          18  151 min     Crime, Drama, Thriller
# 72          Django Unchained          18  165 min             Drama, Western
# 165  The Wolf of Wall Street          18  180 min   Biography, Comedy, Crime
# 167           Shutter Island          15  138 min          Mystery, Thriller
#
#      rating                                              about  \
# 13      8.8  A thief who steals corporate secrets through t...
# ...

# %%
'''
Отфильтруем все нечисловые колонки
'''

# %%
dtypes = dataset.dtypes
dtypes
# Out:
# poster               object
# title                object
# certificate          object
# runtime              object
# genre                object
# rating              float64
# about                object
# director             object
# stars                object
# votes                object
# gross_earn          float64
# runtime_clear         int64
# gross_earn_clear    float64
# dtype: object

# %%
obj_dtypes = dtypes[dtypes=='object']
obj_dtypes
# Out:
# poster         object
# title          object
# certificate    object
# runtime        object
# genre          object
# about          object
# director       object
# stars          object
# votes          object
# dtype: object

# %%
new_columns = num_dtypes.index
new_columns
# Out:
# Index(['rating', 'gross_earn', 'runtime_clear', 'gross_earn_clear'], dtype='object')

# %%
filtered_dataset_8 = dataset[obj_dtypes.index]
filtered_dataset_8.head()
# Out:
#                                               poster  \
# 0  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 1  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 2  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 3  https://m.media-amazon.com/images/S/sash/4Fyxw...
# 4  https://m.media-amazon.com/images/S/sash/4Fyxw...
#
#                       title certificate  runtime                      genre  \
# 0  The Shawshank Redemption          15  142 min                      Drama
# 1            Hababam Sinifi         12A   87 min              Comedy, Drama
# 2             The Godfather           X  175 min               Crime, Drama
# 3    The Godfather: Part II           X  202 min               Crime, Drama
# 4          Schindler's List          15  195 min  Biography, Drama, History
#
#                                                about              director  \
# 0  Two imprisoned men bond over a number of years...        Frank Darabont
# ...

# %%
'''
Сгруппируем датасет по классам фильмов и рассчитаем по ним среднее значение доходов с фильмов
'''

# %%
groups = dataset.groupby(['certificate', 'gross_earn_clear'])
groups

# %%
groups_mean = groups['certificate', 'gross_earn_clear'].mean()
groups_mean
# Out:
# C:\Users\Luther\AppData\Local\Temp\ipykernel_23080\2611220626.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   groups_mean = groups['certificate', 'gross_earn_clear'].mean()
#                               gross_earn_clear
# certificate gross_earn_clear
# 12          4.0                            4.0
#             6.0                            6.0
#             8.0                            8.0
#             10.0                          10.0
#             12.0                          12.0
# ...                                        ...
# X           8643.0                      8643.0
#             10495.0                    10495.0
#             11129.0                    11129.0
#             13497.0                    13497.0
#             23291.0                    23291.0
#
# [4099 rows x 1 columns]
